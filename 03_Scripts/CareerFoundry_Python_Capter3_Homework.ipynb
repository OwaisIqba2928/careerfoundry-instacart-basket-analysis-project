# %% [markdown]
# # 01. Importing Libraries

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing Data

# %%
# Telling Python to remember the main folder path
path = r'C:\Users\Asus\Music\CareerFoundry_Python_Session'

# Simplifying the import function by combining the path
df = pd.read_csv(os.path.join(path, 'orders.csv'), index_col=False)

# Checking the first few rows of the dataset
df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# # 03. Exploring Data with Pandas

# %%
# First 5 rows of the dataset
df.head()

# Last 5 rows of the dataset
df.tail()

# Getting the shape of the DataFrame (rows, columns)
df.shape

# Detailed info about the DataFrame including data types and memory usage
df.info()

# Getting the data types of each column
df.dtypes

# Listing all column names
df.columns

# Summary statistics for numeric columns
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# ...

# %% [markdown]
# # 04. Importing Datasets as Lists

# %%
# Creating a list of necessary columns to import
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# Import the "orders.csv" data set into the notebook using the os library and the vars_list shortcut
df = pd.read_csv(os.path.join(path, 'orders.csv'), usecols=vars_list)

# Print the first 5 rows of the data frame
df.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# #  Importing and Exploring the "products.csv" DataFrame

# %%
# Import the "products.csv" file into the notebook
df_prods = pd.read_csv(os.path.join(path, 'products.csv'), index_col=False)

# Print the first 20 rows of the df_prods dataframe
df_prods.head(20)

# Print the last 35 rows of the df_prods dataframe
df_prods.tail(35)
# Out:
#        product_id                                       product_name  \
# 49653       49654                   Teriyaki Sauce, Sesame, Original
# 49654       49655                                        Apple Cider
# 49655       49656                         Masada Kosher Pocket Bread
# 49656       49657                                  Cabernet Tomatoes
# 49657       49658                         Brie with Herbs Foil Wedge
# 49658       49659                            Organic Creamed Coconut
# 49659       49660                        Professionals Sleek Shampoo
# 49660       49661                                              Porto
# 49661       49662                       Bacon Cheddar Pretzel Pieces
# 49662       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
# 49663       49664                     Lemon Cayenne Drinking Vinegar
# 49664       49665      Super Dark Coconut Ash & Banana Chocolate Bar
# 49665       49666                      Ginger Snaps Snacking Cookies
# ...
